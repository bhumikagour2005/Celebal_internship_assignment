# %%
pip install numpy pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %% [markdown]
# <h4>Reading and Writing data<h4>

# %%
df=pd.read_csv('../data/daily_dataset.csv')
households=pd.read_csv('../data/informations_households.csv')
holidays=pd.read_csv('../data/uk_bank_holidays.csv')
Weather_daily=pd.read_csv('../data/weather_daily_darksky.csv')
Weather_hourly=pd.read_csv('../data/weather_hourly_darksky.csv')
